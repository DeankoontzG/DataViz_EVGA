# %%
import pandas as pd

# 1. Définir le nom du fichier (assure-toi qu'il est dans le même dossier)
file_name = '/Users/bgdu69/Documents/Hackermann/DataViz/DataViz_EVGA/data/exported/country_month_cleaned.csv'

df = pd.read_csv(file_name)

df['precipitation'] = df['precipitation'] * 625

print(df.head(5))

output_file = '/Users/bgdu69/Documents/Hackermann/DataViz/DataViz_EVGA/data/exported/country_month_cleaned_V2.csv'
df.to_csv(output_file, index=False)
# Out:
#    country  year  month  temperature   humidity  precipitation  wind_speed  \
# 0  Algeria  2022      8    27.477951  45.825000       4.730903    9.219479
# 1  Algeria  2022      9    25.527083  51.278333      22.916667   10.410056
# 2  Algeria  2022     10    22.300954  47.443683      11.920363    7.919207
# 3  Algeria  2022     11    16.014597  59.010972      53.706597   12.111986
# 4  Algeria  2022     12    13.930040  58.589113      19.732863   10.010067
#
#    wetbulb_temperature  WUE_FixedApproachDirect(L/KWh)  \
# 0            66.174081                        1.655349
# 1            64.770231                        1.646814
# 2            58.941823                        1.601366
# 3            52.015701                        1.532359
# 4            48.786061                        1.493769
#
#    WUE_FixedColdWaterDirect(L/KWh)  ...  Pct Gas consumption  \
# 0                         1.346765  ...               68.666
# ...
