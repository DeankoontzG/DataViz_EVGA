# %% [markdown]
# # About this notebook
#
# This notebook aims to explore the Water Efficient Dataset For African Countries, and perform some basic data analysis and visualization.

# %% [markdown]
# ### 0. Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Data loading

# %%
raw_df = pd.read_csv("../data/Africa_countries_WUE_data.csv")
raw_df.head()

# %% [markdown]
# ### 2. Dataset Overview

# %%
# General info (types, non-null counts)
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3042168 entries, 0 to 3042167
# Data columns (total 28 columns):
#  #   Column                                                     Dtype
# ---  ------                                                     -----
#  0   Unnamed: 0                                                 int64
#  1   timestamp                                                  object
#  2   city                                                       object
#  3   temperature                                                float64
#  4   precipitation                                              float64
#  5   wind_speed                                                 float64
#  6   humidity                                                   int64
#  7   country                                                    object
#  8   wetbulb_temperature                                        float64
#  9   climate_region                                             object
#  10  Other renewables (including geothermal and biomass) - TWh  float64
#  11  Biofuels consumption - TWh                                 float64
#  12  Solar consumption - TWh                                    float64
#  13  Wind consumption - TWh                                     float64
#  14  Hydro consumption - TWh                                    float64
#  15  Nuclear consumption - TWh                                  float64
#  16  Gas consumption - TWh                                      float64
#  17  Coal consumption - TWh                                     float64
#  18  Oil consumption - TWh                                      float64
#  19  Total renewables - TWh                                     float64
#  20  Total fossil fuels - TWh                                   float64
#  21  Total energy - TWh                                         float64
#  22  Low carbon - TWh                                           float64
#  23  Other - TWh                                                float64
#  24  WUE_FixedApproachDirect(L/KWh)                             float64
#  25  WUE_FixedColdWaterDirect(L/KWh)                            float64
#  26  WUE_Indirect(L/KWh)                                        float64
#  27  Leakages (%)                                               float64
# dtypes: float64(22), int64(2), object(4)
# memory usage: 649.9+ MB

# %%
# Summary statistics for numeric variables
raw_df.describe().T
# Out:
#                                                         count           mean  \
# Unnamed: 0                                          3042168.0  297043.907015
# temperature                                         3042168.0      23.976088
# precipitation                                       3042168.0       0.131713
# wind_speed                                          3042168.0      11.858958
# humidity                                            3042168.0      57.336524
# wetbulb_temperature                                 3042168.0      63.381826
# Other renewables (including geothermal and biom...  3042168.0       0.000017
# Biofuels consumption - TWh                          3042168.0       0.000015
# Solar consumption - TWh                             3042168.0    5531.175874
# Wind consumption - TWh                              3042168.0    7733.492389
# Hydro consumption - TWh                             3042168.0   42005.477933
# Nuclear consumption - TWh                           3042168.0    2980.323016
# Gas consumption - TWh                               3042168.0  403476.126207
# Coal consumption - TWh                              3042168.0  310215.998468
# Oil consumption - TWh                               3042168.0  347958.656183
# Total renewables - TWh                              3042168.0   57846.162581
# Total fossil fuels - TWh                            3042168.0  208233.127030
# Total energy - TWh                                  3042168.0  276340.954074
# Low carbon - TWh                                    3042168.0   60826.485596
# Other - TWh                                         3042168.0    1327.866690
# WUE_FixedApproachDirect(L/KWh)                      3042168.0       1.625833
# WUE_FixedColdWaterDirect(L/KWh)                     3042168.0       1.332448
# WUE_Indirect(L/KWh)                                 3042168.0       3.268346
# Leakages (%)                                        3042168.0       0.355044
#
#                                                              std          min  \
# Unnamed: 0                                          2.165308e+05     0.000000
# temperature                                         6.822991e+00    -5.500000
# precipitation                                       6.957367e-01     0.000000
# wind_speed                                          7.487500e+00     0.000000
# humidity                                            2.668910e+01     2.000000
# wetbulb_temperature                                 9.841182e+00    18.071341
# Other renewables (including geothermal and biom...  7.131780e-05     0.000000
# Biofuels consumption - TWh                          7.012075e-05     0.000000
# Solar consumption - TWh                             1.425453e+04     0.000000
# Wind consumption - TWh                              2.049193e+04     0.000000
# Hydro consumption - TWh                             7.724447e+04     0.000000
# Nuclear consumption - TWh                           1.596226e+04     0.000000
# Gas consumption - TWh                               1.421299e+06     0.000000
# Coal consumption - TWh                              1.483460e+06     0.000000
# Oil consumption - TWh                               1.024247e+06     0.000000
# Total renewables - TWh                              9.113539e+04    87.596356
# Total fossil fuels - TWh                            4.973835e+05     0.000000
# Total energy - TWh                                  5.591728e+05  2561.125529
# Low carbon - TWh                                    9.606817e+04    87.596356
# Other - TWh                                         7.111899e+03     0.000000
# WUE_FixedApproachDirect(L/KWh)                      8.176929e-02     0.941590
# WUE_FixedColdWaterDirect(L/KWh)                     1.327831e-01     1.173174
# WUE_Indirect(L/KWh)                                 1.572938e+00     0.001000
# Leakages (%)                                        8.870722e-02     0.170000
#
#                                                               25%  \
# Unnamed: 0                                          121880.750000
# temperature                                             19.800000
# precipitation                                            0.000000
# wind_speed                                               6.100000
# humidity                                                35.000000
# wetbulb_temperature                                     56.344064
# Other renewables (including geothermal and biom...       0.000000
# Biofuels consumption - TWh                               0.000000
# Solar consumption - TWh                                199.198652
# Wind consumption - TWh                                   0.000000
# Hydro consumption - TWh                                  0.000000
# Nuclear consumption - TWh                                0.000000
# Gas consumption - TWh                                    0.000000
# Coal consumption - TWh                                   0.000000
# Oil consumption - TWh                                    0.000000
# Total renewables - TWh                                1792.787871
# Total fossil fuels - TWh                              3585.575741
# Total energy - TWh                                   13287.721864
# Low carbon - TWh                                      1792.787871
# Other - TWh                                              0.000000
# WUE_FixedApproachDirect(L/KWh)                           1.586134
# WUE_FixedColdWaterDirect(L/KWh)                          1.207874
# WUE_Indirect(L/KWh)                                      1.850851
# Leakages (%)                                             0.258000
#
#                                                               50%  \
# Unnamed: 0                                          252176.500000
# temperature                                             24.200000
# precipitation                                            0.000000
# wind_speed                                              10.300000
# humidity                                                62.000000
# wetbulb_temperature                                     64.635844
# Other renewables (including geothermal and biom...       0.000000
# Biofuels consumption - TWh                               0.000000
# Solar consumption - TWh                                597.595957
# Wind consumption - TWh                                   0.000000
# Hydro consumption - TWh                               5956.552207
# Nuclear consumption - TWh                                0.000000
# Gas consumption - TWh                                    0.000000
# Coal consumption - TWh                                   0.000000
# Oil consumption - TWh                                    0.000000
# Total renewables - TWh                                8195.601694
# Total fossil fuels - TWh                             16493.648409
# Total energy - TWh                                   45417.292720
# Low carbon - TWh                                      8195.601694
# Other - TWh                                              0.000000
# WUE_FixedApproachDirect(L/KWh)                           1.652570
# WUE_FixedColdWaterDirect(L/KWh)                          1.304504
# WUE_Indirect(L/KWh)                                      3.235424
# Leakages (%)                                             0.397200
#
#                                                              75%           max
# Unnamed: 0                                          4.462772e+05  8.783990e+05
# temperature                                         2.810000e+01  4.930000e+01
# precipitation                                       0.000000e+00  1.037000e+02
# wind_speed                                          1.620000e+01  6.480000e+01
# humidity                                            8.000000e+01  1.000000e+02
# wetbulb_temperature                                 7.174337e+01  9.199650e+01
# Other renewables (including geothermal and biom...  9.959933e-07  4.140322e-04
# Biofuels consumption - TWh                          9.959933e-07  4.140322e-04
# Solar consumption - TWh                             2.788781e+03  6.442084e+04
# Wind consumption - TWh                              1.124887e+03  8.496847e+04
# Hydro consumption - TWh                             3.983973e+04  3.404305e+05
# Nuclear consumption - TWh                           0.000000e+00  8.847232e+04
# Gas consumption - TWh                               4.063653e+04  7.241771e+06
# Coal consumption - TWh                              5.975960e+02  8.221263e+06
# Oil consumption - TWh                               0.000000e+00  5.082300e+06
# Total renewables - TWh                              8.639530e+04  3.448129e+05
# Total fossil fuels - TWh                            1.603948e+05  2.300983e+06
# Total energy - TWh                                  2.726875e+05  2.590100e+06
# Low carbon - TWh                                    8.639530e+04  3.448129e+05
# Other - TWh                                         0.000000e+00  3.941836e+04
# WUE_FixedApproachDirect(L/KWh)                      1.688765e+00  1.707257e+00
# WUE_FixedColdWaterDirect(L/KWh)                     1.444016e+00  2.130202e+00
# WUE_Indirect(L/KWh)                                 4.955351e+00  5.337428e+00
# Leakages (%)                                        3.972000e-01  5.500000e-01

# %%
# Show the number of rows / columns
raw_df.shape
# Out:
# (3042168, 28)

# %%
# List unique countries
sorted(raw_df["country"].unique())
# Out:
# ['Algeria',
#  'Benin',
#  'Botswana',
#  'Burkina Faso',
#  'Burundi',
#  'Cameroon',
#  'Cape Verde',
#  'Central African Republic',
#  'Chad',
#  'Egypt',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Guinea',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Libya',
#  'Madagascar',
#  'Malawi',
#  'Mali',
#  'Mauritania',
#  'Morocco',
#  'Mozambique',
#  'Namibia',
#  'Niger',
#  'Nigeria',
#  'Senegal',
#  'Seychelles',
#  'Sierra Leone',
#  'Somalia',
#  'South Africa',
#  'South Sudan',
#  'Sudan',
#  'Tanzania',
#  'Togo',
#  'Tunisia',
#  'Uganda',
#  'Zambia',
#  'Zimbabwe']

# %%
# List climate regions
sorted(raw_df["climate_region"].unique())
# Out:
# ['Desert', 'Mediterranean', 'Rainforest', 'Savana', 'Steppe']

# %%
# Count missing values per column
raw_df.isna().sum().sort_values(ascending=False)
# Out:
# Unnamed: 0                                                   0
# timestamp                                                    0
# WUE_Indirect(L/KWh)                                          0
# WUE_FixedColdWaterDirect(L/KWh)                              0
# WUE_FixedApproachDirect(L/KWh)                               0
# Other - TWh                                                  0
# Low carbon - TWh                                             0
# Total energy - TWh                                           0
# Total fossil fuels - TWh                                     0
# Total renewables - TWh                                       0
# Oil consumption - TWh                                        0
# Coal consumption - TWh                                       0
# Gas consumption - TWh                                        0
# Nuclear consumption - TWh                                    0
# Hydro consumption - TWh                                      0
# Wind consumption - TWh                                       0
# Solar consumption - TWh                                      0
# Biofuels consumption - TWh                                   0
# Other renewables (including geothermal and biomass) - TWh    0
# climate_region                                               0
# wetbulb_temperature                                          0
# country                                                      0
# humidity                                                     0
# wind_speed                                                   0
# precipitation                                                0
# temperature                                                  0
# city                                                         0
# Leakages (%)                                                 0
# dtype: int64

# %% [markdown]
# ### 3. Convert timestamp and extract date components

# %%
raw_df["timestamp"] = pd.to_datetime(raw_df["timestamp"])
raw_df["year"] = raw_df["timestamp"].dt.year
raw_df["month"] = raw_df["timestamp"].dt.month
raw_df
# Out:
#          Unnamed: 0           timestamp            city  temperature  \
# 0                 0 2022-08-20 00:00:00         Yaoundé         19.7
# 1            158112 2022-08-20 00:00:00      Nouakchott         26.2
# 2            149328 2022-08-20 00:00:00         Barentu         25.1
# 3            140544 2022-08-20 00:00:00       Mendefera         16.5
# 4            131760 2022-08-20 00:00:00           Assab         32.0
# ...             ...                 ...             ...          ...
# 3042163       14639 2024-08-04 23:00:00         Tangier         22.9
# 3042164       11711 2024-08-04 23:00:00             Fes         28.3
# 3042165        8783 2024-08-04 23:00:00       Marrakech         28.6
# 3042166        2927 2024-08-04 23:00:00      Casablanca         22.5
# 3042167       73175 2024-08-04 23:00:00  Port Elizabeth         11.7
#
#          precipitation  wind_speed  humidity       country  \
# 0                  0.0         6.8        98      Cameroon
# 1                  0.9        12.6        81    Mauritania
# 2                  0.0        12.6        73       Eritrea
# 3                  0.4        11.9        82       Eritrea
# 4                  0.0        14.5        62       Eritrea
# ...                ...         ...       ...           ...
# 3042163            0.0         6.8        70       Morocco
# 3042164            0.0         6.8        24       Morocco
# 3042165            0.0         2.9        24       Morocco
# 3042166            0.0         4.7        77       Morocco
# 3042167            0.0        34.2        63  South Africa
#
#          wetbulb_temperature climate_region  ...  Total fossil fuels - TWh  \
# 0                  67.032045         Desert  ...              5.224696e+04
# 1                  74.523261         Steppe  ...              8.366343e+03
# 2                  70.618841         Steppe  ...              3.685175e+03
# 3                  57.920598         Steppe  ...              3.685175e+03
# 4                  79.044228         Steppe  ...              3.685175e+03
# ...                      ...            ...  ...                       ...
# 3042163            66.169931         Savana  ...              2.967765e+05
# 3042164            60.330565         Savana  ...              2.967765e+05
# 3042165            60.715561         Savana  ...              2.967765e+05
# 3042166            67.167116         Savana  ...              2.967765e+05
# 3042167            46.129720  Mediterranean  ...              1.758754e+06
#
#          Total energy - TWh  Low carbon - TWh   Other - TWh  \
# 0              1.386423e+05      86395.301188      0.000000
# 1              1.328772e+04       3585.575741      0.000000
# 2              3.784774e+03         99.599326      0.000000
# 3              3.784774e+03         99.599326      0.000000
# 4              3.784774e+03         99.599326      0.000000
# ...                     ...               ...           ...
# 3042163        3.750000e+05      65960.056062      0.000000
# 3042164        3.750000e+05      65960.056062      0.000000
# 3042165        3.750000e+05      65960.056062      0.000000
# 3042166        3.750000e+05      65960.056062      0.000000
# 3042167        2.056666e+06     258494.218641  39418.360196
#
#          WUE_FixedApproachDirect(L/KWh)  WUE_FixedColdWaterDirect(L/KWh)  \
# 0                              1.666913                         1.344436
# 1                              1.697710                         1.513311
# 2                              1.684314                         1.418134
# 3                              1.600773                         1.216367
# 4                              1.706000                         1.642989
# ...                                 ...                              ...
# 3042163                        1.662003                         1.328683
# 3042164                        1.621329                         1.241985
# 3042165                        1.624409                         1.246628
# 3042166                        1.667657                         1.346973
# 3042167                        1.468455                         1.176626
#
#          WUE_Indirect(L/KWh)  Leakages (%)  year  month
# 0                   4.070095        0.5250  2022      8
# 1                   3.237921        0.3972  2022      8
# 2                   3.788000        0.3972  2022      8
# 3                   3.788000        0.3972  2022      8
# 4                   3.788000        0.3972  2022      8
# ...                      ...           ...   ...    ...
# 3042163             1.606216        0.3972  2024      8
# 3042164             1.606216        0.3972  2024      8
# 3042165             1.606216        0.3972  2024      8
# 3042166             1.606216        0.3972  2024      8
# 3042167             1.850851        0.2220  2024      8
#
# [3042168 rows x 30 columns]

# %% [markdown]
# ### 4. Create lightweight datasets (per country per year, and per country per month)

# %%
# Columns that do not change within each country-year
energy_cols = [
    "Total energy - TWh",
    "Total renewables - TWh",
    "Total fossil fuels - TWh",
    "Coal consumption - TWh",
    "Gas consumption - TWh",
    "Oil consumption - TWh",
    "Nuclear consumption - TWh",
    "Solar consumption - TWh",
    "Hydro consumption - TWh",
    "Wind consumption - TWh",
    "Biofuels consumption - TWh",
    "Low carbon - TWh",
    "Other renewables (including geothermal and biomass) - TWh",
    "Other - TWh",
]

# Weather / water efficiency columns to average
metric_cols = [
    "temperature",
    "humidity",
    "precipitation",
    "wind_speed",
    "wetbulb_temperature",
    "WUE_FixedApproachDirect(L/KWh)",
    "WUE_FixedColdWaterDirect(L/KWh)",
    "WUE_Indirect(L/KWh)",
    "Leakages (%)",
]

# %%
group_cols = ["city", "country", "year", "month"]

city_month_df = raw_df.groupby(group_cols).agg(
    {col: "mean" for col in metric_cols} |
    {col: "sum" for col in energy_cols} |
    {"climate_region": "first"}
).reset_index()


country_year_df = city_month_df.groupby(["country","year"]).agg(
    {col: "mean" for col in metric_cols} |
    {col: "mean" for col in energy_cols} |
    {"climate_region": lambda x: x.mode()[0] if not x.empty else None}
).reset_index()

country_year_df.head(20)

country_year_df["Pct renewables"] = 100*country_year_df["Total renewables - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct fossil fuels"] = 100*country_year_df["Total fossil fuels - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Coal consumption"] = 100*country_year_df["Coal consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Gas consumption"] = 100*country_year_df["Gas consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Oil consumption"] = 100*country_year_df["Oil consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Nuclear consumption"] = 100*country_year_df["Nuclear consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Solar consumption"] = 100*country_year_df["Solar consumption - TWh"]/country_year_df["Total energy - TWh"]

country_year_df["Pct Hydro consumption"] = 100*country_year_df["Hydro consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Wind consumption"] = 100*country_year_df["Wind consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Biofuels consumption"] = 100*country_year_df["Biofuels consumption - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Low carbon"] = 100*country_year_df["Low carbon - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Other renewables"] = 100*country_year_df["Other - TWh"]/country_year_df["Total energy - TWh"]
country_year_df["Pct Other"] = 100*country_year_df["Other renewables (including geothermal and biomass) - TWh"]/country_year_df["Total energy - TWh"]

country_year_df.to_csv("../data/exported/country_year_cleaned.csv", index=False)
country_year_df.head(50)
# Out:
#                      country  year  temperature   humidity  precipitation  \
# 0                    Algeria  2022    21.050125  52.429420       0.036162
# 1                    Algeria  2023    18.747702  57.254442       0.071375
# 2                    Algeria  2024    19.829916  56.287229       0.031627
# 3                      Benin  2022    26.008916  72.901366       0.194354
# 4                      Benin  2023    27.578756  69.784622       0.246798
# 5                   Botswana  2022    24.013353  37.903167       0.051147
# 6                   Botswana  2023    21.200044  42.698953       0.056804
# 7               Burkina Faso  2022    26.891322  49.167114       0.165307
# 8               Burkina Faso  2023    30.099376  39.116609       0.145077
# 9                    Burundi  2022    20.273354  67.002499       0.146164
# 10                   Burundi  2023    19.706109  71.051640       0.203279
# 11                  Cameroon  2022    22.977180  73.170470       0.243951
# 12                  Cameroon  2023    24.993985  66.838310       0.322393
# 13                Cape Verde  2022    25.439053  75.614026       0.049544
# 14                Cape Verde  2023    23.476143  76.244881       0.020942
# 15  Central African Republic  2022    24.629690  74.691100       0.187122
# 16  Central African Republic  2023    26.718108  63.223079       0.182148
# 17                      Chad  2022    26.660975  47.820860       0.099101
# 18                      Chad  2023    29.920014  34.830119       0.087420
# 19                     Egypt  2022    25.133854  50.094453       0.002708
# 20                     Egypt  2023    24.276820  43.943936       0.004020
# 21         Equatorial Guinea  2022    24.187969  84.420559       0.361527
# 22         Equatorial Guinea  2023    25.138883  82.570357       0.370199
# 23                   Eritrea  2022    22.866931  56.885520       0.083657
# 24                   Eritrea  2023    24.053578  52.601642       0.077556
# 25                  Ethiopia  2022    17.842126  63.458141       0.174608
# 26                  Ethiopia  2023    19.419809  59.217836       0.263290
# 27                     Gabon  2022    24.022077  83.832414       0.299333
# 28                     Gabon  2023    24.855206  80.547168       0.255811
# 29                     Ghana  2022    25.647608  76.087037       0.168774
# 30                     Ghana  2023    27.112025  73.889846       0.232923
# 31                    Guinea  2022    23.771024  74.201837       0.533897
# 32                    Guinea  2023    25.766288  66.159463       0.399089
# 33                     Kenya  2022    20.027327  69.541849       0.131474
# 34                     Kenya  2023    20.616631  68.022736       0.178065
# 35                   Lesotho  2022    16.744370  48.017304       0.142711
# 36                   Lesotho  2023    14.066356  49.898281       0.103268
# 37                   Liberia  2022    24.646204  80.351357       0.418160
# 38                   Liberia  2023    25.866633  79.371685       0.434747
# 39                     Libya  2022    22.868305  56.429034       0.012183
# 40                     Libya  2023    21.197764  55.191323       0.020506
# 41                     Libya  2024    21.915952  53.341706       0.014867
# 42                Madagascar  2022    20.952214  69.874593       0.136936
# 43                Madagascar  2023    20.643020  76.491238       0.262514
# 44                    Malawi  2022    23.202200  50.431020       0.088323
# 45                    Malawi  2023    19.941742  71.812896       0.192213
# 46                      Mali  2022    28.209755  36.606213       0.108128
# 47                      Mali  2023    30.984934  27.343299       0.071474
# 48                Mauritania  2022    27.863055  41.026704       0.039470
# 49                Mauritania  2023    27.651822  37.900457       0.011469
#
#     wind_speed  wetbulb_temperature  WUE_FixedApproachDirect(L/KWh)  \
# 0     9.934159            58.137579                        1.585931
# 1    10.081608            55.270413                        1.554531
# 2    10.881641            56.880095                        1.575103
# 3     9.639259            71.377913                        1.681258
# 4    11.112384            72.975527                        1.687514
# 5    14.719801            57.945186                        1.590830
# 6    12.291760            55.703792                        1.565259
# 7    10.926416            65.248129                        1.641316
# 8    12.335318            66.394838                        1.648120
# 9     5.800551            60.538692                        1.619585
# 10    5.840192            60.583900                        1.618535
# 11    5.808941            66.115261                        1.653709
# 12    6.383244            67.153253                        1.658900
# 13   19.483753            71.846492                        1.686896
# 14   21.612124            68.641208                        1.672034
# 15    4.590074            69.356865                        1.673415
# 16    5.603567            69.083450                        1.670781
# 17   11.400112            64.413583                        1.636223
# 18   12.297438            64.339122                        1.635325
# 19   14.170960            63.542916                        1.633617
# 20   15.030820            59.827627                        1.601469
# 21    7.273122            71.739147                        1.687200
# 22    7.683499            72.879443                        1.690948
# 23   10.928332            62.164250                        1.618631
# 24   11.794937            62.626611                        1.622421
# 25    8.313649            55.797245                        1.574853
# 26    9.109840            57.101963                        1.587212
# 27    6.083603            71.230227                        1.685278
# 28    6.210328            71.763935                        1.686843
# 29    9.293297            71.770408                        1.685196
# 30   10.415866            73.489027                        1.691192
# 31    5.648239            67.982128                        1.664020
# 32    6.754118            68.605462                        1.666873
# 33    9.784157            60.887869                        1.616578
# 34   10.195240            61.332618                        1.618763
# 35   11.092428            50.228563                        1.507538
# 36    9.592527            46.853061                        1.458695
# 37    8.030386            71.402808                        1.684192
# 38    8.671380            73.146637                        1.690358
# 39   15.631288            62.219322                        1.624185
# 40   17.888248            59.000546                        1.595171
# 41   18.292560            59.626413                        1.601221
# 42   10.876568            62.369000                        1.623385
# 43   10.376644            63.539818                        1.631650
# 44   10.356208            60.811878                        1.619676
# 45    7.613008            61.254455                        1.620378
# 46   13.503886            63.185793                        1.625496
# 47   14.127144            63.190213                        1.624536
# 48   17.296030            64.408374                        1.635299
# 49   19.590565            62.251005                        1.621551
#
#     WUE_FixedColdWaterDirect(L/KWh)  WUE_Indirect(L/KWh)  ...  \
# 0                          1.263681             1.413949  ...
# 1                          1.251926             1.413949  ...
# 2                          1.250590             1.413949  ...
# 3                          1.451900             1.462264  ...
# 4                          1.488757             1.462264  ...
# 5                          1.244004             2.015036  ...
# 6                          1.237575             2.015036  ...
# 7                          1.353463             4.562714  ...
# 8                          1.373678             4.562714  ...
# 9                          1.253686             5.270062  ...
# 10                         1.258039             5.270062  ...
# 11                         1.349207             4.070095  ...
# 12                         1.370117             4.070095  ...
# 13                         1.452455             0.542000  ...
# 14                         1.384740             0.542000  ...
# 15                         1.405084             5.337428  ...
# 16                         1.402990             5.337428  ...
# 17                         1.339129             0.001000  ...
# 18                         1.339049             0.001000  ...
# 19                         1.316878             1.470484  ...
# 20                         1.278620             1.470484  ...
# 21                         1.448026             2.701209  ...
# 22                         1.476266             2.701209  ...
# 23                         1.310923             3.788000  ...
# 24                         1.316251             3.788000  ...
# 25                         1.214851             5.128685  ...
# 26                         1.225402             5.128685  ...
# 27                         1.436094             3.235424  ...
# 28                         1.449823             3.235424  ...
# 29                         1.454481             2.771613  ...
# 30                         1.496107             2.771613  ...
# 31                         1.384184             5.322087  ...
# 32                         1.397454             5.322087  ...
# 33                         1.273536             3.177583  ...
# 34                         1.282602             3.177583  ...
# 35                         1.209085             5.337428  ...
# 36                         1.227265             5.337428  ...
# 37                         1.444826             5.337428  ...
# 38                         1.486841             5.337428  ...
# 39                         1.297800             1.411107  ...
# 40                         1.267788             1.411107  ...
# 41                         1.272522             1.411107  ...
# 42                         1.304990             4.816583  ...
# 43                         1.322077             4.816583  ...
# 44                         1.262627             5.121524  ...
# 45                         1.275618             5.121524  ...
# 46                         1.326765             5.304923  ...
# 47                         1.329503             5.304923  ...
# 48                         1.341447             3.237921  ...
# 49                         1.305968             3.237921  ...
#
#     Pct Gas consumption  Pct Oil consumption  Pct Nuclear consumption  \
# 0            570.863557           257.261727                      0.0
# 1            570.863557           257.261727                      0.0
# 2            570.863557           257.261727                      0.0
# 3             48.901099             0.000000                      0.0
# 4             48.901099             0.000000                      0.0
# 5              0.000000             0.000000                      0.0
# 6              0.000000             0.000000                      0.0
# 7              0.000000             0.000000                      0.0
# 8              0.000000             0.000000                      0.0
# 9              0.000000             0.000000                      0.0
# 10             0.000000             0.000000                      0.0
# 11            29.310345             0.000000                      0.0
# 12            29.310345             0.000000                      0.0
# 13             0.000000             0.000000                      0.0
# 14             0.000000             0.000000                      0.0
# 15             0.000000             0.000000                      0.0
# 16             0.000000             0.000000                      0.0
# 17             0.000000             0.000000                      0.0
# 18             0.000000             0.000000                      0.0
# 19           279.594219           196.220206                      0.0
# 20           279.594219           196.220206                      0.0
# 21            66.666667             0.000000                      0.0
# 22            66.666667             0.000000                      0.0
# 23             0.000000             0.000000                      0.0
# 24             0.000000             0.000000                      0.0
# 25             0.000000             0.000000                      0.0
# 26             0.000000             0.000000                      0.0
# 27            39.041096             0.000000                      0.0
# 28            39.041096             0.000000                      0.0
# 29            63.244444             0.000000                      0.0
# 30            63.244444             0.000000                      0.0
# 31             0.000000             0.000000                      0.0
# 32             0.000000             0.000000                      0.0
# 33             0.000000             0.000000                      0.0
# 34             0.000000             0.000000                      0.0
# 35             0.000000             0.000000                      0.0
# 36             0.000000             0.000000                      0.0
# 37             0.000000             0.000000                      0.0
# 38             0.000000             0.000000                      0.0
# 39            69.000964             0.000000                      0.0
# 40            69.000964             0.000000                      0.0
# 41            69.000964             0.000000                      0.0
# 42             0.000000             0.000000                      0.0
# 43             0.000000             0.000000                      0.0
# 44             0.000000             0.000000                      0.0
# 45             0.000000             0.000000                      0.0
# 46             0.000000             0.000000                      0.0
# 47             0.000000             0.000000                      0.0
# 48             0.000000             0.000000                      0.0
# 49             0.000000             0.000000                      0.0
#
#     Pct Solar consumption  Pct Hydro consumption  Pct Wind consumption  \
# 0                0.748469               0.011340              0.011340
# 1                0.748469               0.011340              0.011340
# 2                0.748469               0.011340              0.011340
# 3                1.098901               0.000000              0.000000
# 4                1.098901               0.000000              0.000000
# 5                0.233100               0.000000              0.000000
# 6                0.233100               0.000000              0.000000
# 7                5.172414               5.172414              0.000000
# 8                5.172414               5.172414              0.000000
# 9                2.173913              47.826087              0.000000
# 10               2.173913              47.826087              0.000000
# 11               0.246305              61.576355              0.000000
# 12               0.246305              61.576355              0.000000
# 13               2.325581               0.000000             13.953488
# 14               2.325581               0.000000             13.953488
# 15               0.000000             100.000000              0.000000
# 16               0.000000             100.000000              0.000000
# 17               0.000000               0.000000              2.857143
# 18               0.000000               0.000000              2.857143
# 19               2.487195               6.132620              2.542568
# 20               2.487195               6.132620              2.542568
# 21               0.000000              32.653061              0.000000
# 22               0.000000              32.653061              0.000000
# 23               2.631579               0.000000              0.000000
# 24               2.631579               0.000000              0.000000
# 25               0.259403              95.654994              3.826200
# 26               0.259403              95.654994              3.826200
# 27               0.000000              33.904110              0.000000
# 28               0.000000              33.904110              0.000000
# 29               0.577778              33.333333              0.000000
# 30               0.577778              33.333333              0.000000
# 31               0.657895              65.789474              0.000000
# 32               0.657895              65.789474              0.000000
# 33               3.025478              24.203822             17.038217
# 34               3.025478              24.203822             17.038217
# 35               0.000000              53.763441              0.000000
# 36               0.000000              53.763441              0.000000
# 37               0.000000              67.088608              0.000000
# 38               0.000000              67.088608              0.000000
# 39               0.032123               0.000000              0.000000
# 40               0.032123               0.000000              0.000000
# 41               0.032123               0.000000              0.000000
# 42               1.694915              33.050847              0.000000
# 43               1.694915              33.050847              0.000000
# 44              12.592593              77.777778              0.000000
# 45              12.592593              77.777778              0.000000
# 46               0.763359              35.623410              0.000000
# 47               0.763359              35.623410              0.000000
# 48               7.407407              11.111111              8.465608
# 49               7.407407              11.111111              8.465608
#
#     Pct Biofuels consumption  Pct Low carbon  Pct Other renewables  \
# 0               4.730573e-11        0.771150                   0.0
# 1               4.730573e-11        0.771150                   0.0
# 2               4.730573e-11        0.771150                   0.0
# 3               0.000000e+00        1.098901                   0.0
# 4               0.000000e+00        1.098901                   0.0
# 5               0.000000e+00        0.233100                   0.0
# 6               0.000000e+00        0.233100                   0.0
# 7               0.000000e+00       10.344828                   0.0
# 8               0.000000e+00       10.344828                   0.0
# 9               2.173913e-09       52.173913                   0.0
# 10              2.173913e-09       52.173913                   0.0
# 11              4.926108e-10       62.315271                   0.0
# 12              4.926108e-10       62.315271                   0.0
# 13              0.000000e+00       16.279070                   0.0
# 14              0.000000e+00       16.279070                   0.0
# 15              0.000000e+00      100.000000                   0.0
# 16              0.000000e+00      100.000000                   0.0
# 17              2.857143e-09        5.714286                   0.0
# 18              2.857143e-09        5.714286                   0.0
# 19              1.598518e-08       11.162383                   0.0
# 20              1.598518e-08       11.162383                   0.0
# 21              0.000000e+00       32.653061                   0.0
# 22              0.000000e+00       32.653061                   0.0
# 23              0.000000e+00        2.631579                   0.0
# 24              0.000000e+00        2.631579                   0.0
# 25              1.945525e-10       99.935149                   0.0
# 26              1.945525e-10       99.935149                   0.0
# 27              3.424658e-10       34.246575                   0.0
# 28              3.424658e-10       34.246575                   0.0
# 29              8.888889e-11       34.000000                   0.0
# 30              8.888889e-11       34.000000                   0.0
# 31              0.000000e+00       66.447368                   0.0
# 32              0.000000e+00       66.447368                   0.0
# 33              2.308917e-09       90.525478                   0.0
# 34              2.308917e-09       90.525478                   0.0
# 35              0.000000e+00       53.763441                   0.0
# 36              0.000000e+00       53.763441                   0.0
# 37              0.000000e+00       67.088608                   0.0
# 38              0.000000e+00       67.088608                   0.0
# 39              0.000000e+00        0.032123                   0.0
# 40              0.000000e+00        0.032123                   0.0
# 41              0.000000e+00        0.032123                   0.0
# 42              2.118644e-09       36.864407                   0.0
# 43              2.118644e-09       36.864407                   0.0
# 44              3.703704e-09       94.074074                   0.0
# 45              3.703704e-09       94.074074                   0.0
# 46              1.526718e-09       37.913486                   0.0
# 47              1.526718e-09       37.913486                   0.0
# 48              0.000000e+00       26.984127                   0.0
# 49              0.000000e+00       26.984127                   0.0
#
#        Pct Other
# 0   4.730573e-11
# 1   4.730573e-11
# 2   4.730573e-11
# 3   0.000000e+00
# 4   0.000000e+00
# 5   0.000000e+00
# 6   0.000000e+00
# 7   0.000000e+00
# 8   0.000000e+00
# 9   2.173913e-09
# 10  2.173913e-09
# 11  4.926108e-10
# 12  4.926108e-10
# 13  0.000000e+00
# 14  0.000000e+00
# 15  0.000000e+00
# 16  0.000000e+00
# 17  2.857143e-09
# 18  2.857143e-09
# 19  1.598518e-08
# 20  1.598518e-08
# 21  0.000000e+00
# 22  0.000000e+00
# 23  0.000000e+00
# 24  0.000000e+00
# 25  1.945525e-10
# 26  1.945525e-10
# 27  3.424658e-10
# 28  3.424658e-10
# 29  8.888889e-11
# 30  8.888889e-11
# 31  0.000000e+00
# 32  0.000000e+00
# 33  4.625796e-08
# 34  4.625796e-08
# 35  0.000000e+00
# 36  0.000000e+00
# 37  0.000000e+00
# 38  0.000000e+00
# 39  0.000000e+00
# 40  0.000000e+00
# 41  0.000000e+00
# 42  2.118644e-09
# 43  2.118644e-09
# 44  3.703704e-09
# 45  3.703704e-09
# 46  1.526718e-09
# 47  1.526718e-09
# 48  0.000000e+00
# 49  0.000000e+00
#
# [50 rows x 39 columns]

# %%
group_cols = ["city", "country", "year", "month"]

city_month_df = raw_df.groupby(group_cols).agg(
    {col: "mean" for col in metric_cols} |
    {col: "sum" for col in energy_cols} |
    {"climate_region": "first"}
).reset_index()


country_month_df = city_month_df.groupby(["country", "year", "month"]).agg(
    {col: "mean" for col in metric_cols} |
    {col: "mean" for col in energy_cols} |
    {"climate_region": lambda x: x.mode()[0] if not x.empty else None}
).reset_index()


country_month_df["Pct renewables"] = 100*country_month_df["Total renewables - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct fossil fuels"] = 100*country_month_df["Total fossil fuels - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Coal consumption"] = 100*country_month_df["Coal consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Gas consumption"] = 100*country_month_df["Gas consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Oil consumption"] = 100*country_month_df["Oil consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Nuclear consumption"] = 100*country_month_df["Nuclear consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Solar consumption"] = 100*country_month_df["Solar consumption - TWh"]/country_month_df["Total energy - TWh"]

country_month_df["Pct Hydro consumption"] = 100*country_month_df["Hydro consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Wind consumption"] = 100*country_month_df["Wind consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Biofuels consumption"] = 100*country_month_df["Biofuels consumption - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Low carbon"] = 100*country_month_df["Low carbon - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Other renewables"] = 100*country_month_df["Other - TWh"]/country_month_df["Total energy - TWh"]
country_month_df["Pct Other"] = 100*country_month_df["Other renewables (including geothermal and biomass) - TWh"]/country_month_df["Total energy - TWh"]


country_month_df.to_csv("../data/exported/country_month_cleaned.csv", index=False)
country_month_df
# Out:
#       country  year  month  temperature   humidity  precipitation  wind_speed  \
# 0     Algeria  2022      8    27.477951  45.825000       0.007569    9.219479
# 1     Algeria  2022      9    25.527083  51.278333       0.036667   10.410056
# 2     Algeria  2022     10    22.300954  47.443683       0.019073    7.919207
# 3     Algeria  2022     11    16.014597  59.010972       0.085931   12.111986
# 4     Algeria  2022     12    13.930040  58.589113       0.031573   10.010067
# ..        ...   ...    ...          ...        ...            ...         ...
# 601  Zimbabwe  2023      4    20.367338  56.389583       0.022338    9.860856
# 602  Zimbabwe  2023      5    19.200448  50.595430       0.001949    8.872043
# 603  Zimbabwe  2023      6    17.934282  37.919676       0.000278    8.421481
# 604  Zimbabwe  2023      7    14.750717  51.441756       0.003831   10.983378
# 605  Zimbabwe  2023      8    16.361806  46.892708       0.005347   11.617778
#
#      wetbulb_temperature  WUE_FixedApproachDirect(L/KWh)  \
# 0              66.174081                        1.655349
# 1              64.770231                        1.646814
# 2              58.941823                        1.601366
# 3              52.015701                        1.532359
# 4              48.786061                        1.493769
# ..                   ...                             ...
# 601            57.511131                        1.593350
# 602            54.263307                        1.561702
# 603            49.349878                        1.503946
# 604            47.768667                        1.485905
# 605            49.014237                        1.502245
#
#      WUE_FixedColdWaterDirect(L/KWh)  ...  Pct Gas consumption  \
# 0                           1.346765  ...           570.863557
# 1                           1.322567  ...           570.863557
# 2                           1.249112  ...           570.863557
# 3                           1.202260  ...           570.863557
# 4                           1.197700  ...           570.863557
# ..                               ...  ...                  ...
# 601                         1.222612  ...             0.000000
# 602                         1.198727  ...             0.000000
# 603                         1.189221  ...             0.000000
# 604                         1.184692  ...             0.000000
# 605                         1.182520  ...             0.000000
#
#      Pct Oil consumption  Pct Nuclear consumption  Pct Solar consumption  \
# 0             257.261727                      0.0               0.748469
# 1             257.261727                      0.0               0.748469
# 2             257.261727                      0.0               0.748469
# 3             257.261727                      0.0               0.748469
# 4             257.261727                      0.0               0.748469
# ..                   ...                      ...                    ...
# 601             0.000000                      0.0               0.280636
# 602             0.000000                      0.0               0.280636
# 603             0.000000                      0.0               0.280636
# 604             0.000000                      0.0               0.280636
# 605             0.000000                      0.0               0.280636
#
#      Pct Hydro consumption  Pct Wind consumption  Pct Biofuels consumption  \
# 0                 0.011340               0.01134              4.730573e-11
# 1                 0.011340               0.01134              4.730573e-11
# 2                 0.011340               0.01134              4.730573e-11
# 3                 0.011340               0.01134              4.730573e-11
# 4                 0.011340               0.01134              4.730573e-11
# ..                     ...                   ...                       ...
# 601              55.004677               0.00000              9.354537e-10
# 602              55.004677               0.00000              9.354537e-10
# 603              55.004677               0.00000              9.354537e-10
# 604              55.004677               0.00000              9.354537e-10
# 605              55.004677               0.00000              9.354537e-10
#
#      Pct Low carbon  Pct Other renewables     Pct Other
# 0          0.771150                   0.0  4.730573e-11
# 1          0.771150                   0.0  4.730573e-11
# 2          0.771150                   0.0  4.730573e-11
# 3          0.771150                   0.0  4.730573e-11
# 4          0.771150                   0.0  4.730573e-11
# ..              ...                   ...           ...
# 601       56.220767                   0.0  9.354537e-10
# 602       56.220767                   0.0  9.354537e-10
# 603       56.220767                   0.0  9.354537e-10
# 604       56.220767                   0.0  9.354537e-10
# 605       56.220767                   0.0  9.354537e-10
#
# [606 rows x 40 columns]

# %% [markdown]
# ### 5. Compute climate-region summaries

# %%
climate_df = country_year_df.groupby("climate_region").agg({
    "WUE_FixedApproachDirect(L/KWh)": "mean",
    "WUE_FixedColdWaterDirect(L/KWh)": "mean",
    "WUE_Indirect(L/KWh)": "mean",
    "Leakages (%)": "mean",
}).reset_index()

climate_df.to_csv("../data/exported/climate_summary.csv", index=False)
climate_df
# Out:
#   climate_region  WUE_FixedApproachDirect(L/KWh)  \
# 0         Desert                        1.659018
# 1  Mediterranean                        1.567076
# 2     Rainforest                        1.691855
# 3         Savana                        1.629235
# 4         Steppe                        1.611489
#
#    WUE_FixedColdWaterDirect(L/KWh)  WUE_Indirect(L/KWh)  Leakages (%)
# 0                         1.394605             3.296603      0.418211
# 1                         1.242384             1.632400      0.309600
# 2                         1.478954             3.301323      0.397200
# 3                         1.320027             3.371680      0.333891
# 4                         1.313228             3.846037      0.353400
