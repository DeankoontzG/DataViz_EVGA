# %% [markdown]
# # About this notebook
#
# This notebook aims to explore the Water Efficient Dataset For African Countries, and perform some basic data analysis and visualization.

# %% [markdown]
# ### 0. Imports

# %%
import pandas as pd
import numpy as np
# ...

# %% [markdown]
# ### 1. Data loading

# %%
raw_df = pd.read_csv("../data/Africa_countries_WUE_data.csv")
raw_df.head()
# Out:
#    Unnamed: 0            timestamp        city  temperature  precipitation  \
# 0           0  2022-08-20 00:00:00     Yaoundé         19.7            0.0
# 1      158112  2022-08-20 00:00:00  Nouakchott         26.2            0.9
# 2      149328  2022-08-20 00:00:00     Barentu         25.1            0.0
# 3      140544  2022-08-20 00:00:00   Mendefera         16.5            0.4
# 4      131760  2022-08-20 00:00:00       Assab         32.0            0.0
#
#    wind_speed  humidity     country  wetbulb_temperature climate_region  ...  \
# 0         6.8        98    Cameroon            67.032045         Desert  ...
# 1        12.6        81  Mauritania            74.523261         Steppe  ...
# 2        12.6        73     Eritrea            70.618841         Steppe  ...
# 3        11.9        82     Eritrea            57.920598         Steppe  ...
# 4        14.5        62     Eritrea            79.044228         Steppe  ...
#
#    Oil consumption - TWh  Total renewables - TWh  Total fossil fuels - TWh  \
# 0                    0.0            86395.301188              52246.960798
# 1                    0.0             3585.575741               8366.343396
# 2                    0.0               99.599326               3685.175067
# 3                    0.0               99.599326               3685.175067
# 4                    0.0               99.599326               3685.175067
#
#    Total energy - TWh  Low carbon - TWh  Other - TWh  \
# 0       138642.261986      86395.301188          0.0
# 1        13287.721864       3585.575741          0.0
# 2         3784.774393         99.599326          0.0
# 3         3784.774393         99.599326          0.0
# 4         3784.774393         99.599326          0.0
#
#    WUE_FixedApproachDirect(L/KWh)  WUE_FixedColdWaterDirect(L/KWh)  \
# 0                        1.666913                         1.344436
# 1                        1.697710                         1.513311
# 2                        1.684314                         1.418134
# 3                        1.600773                         1.216367
# 4                        1.706000                         1.642989
#
#    WUE_Indirect(L/KWh)  Leakages (%)
# 0             4.070095        0.5250
# 1             3.237921        0.3972
# 2             3.788000        0.3972
# 3             3.788000        0.3972
# 4             3.788000        0.3972
#
# [5 rows x 28 columns]
